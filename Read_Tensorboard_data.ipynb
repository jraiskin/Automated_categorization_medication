# %%
import tensorflow as tf
# getting data directly from a tensorboard log dir
from tensorflow.python.summary import event_multiplexer

import pandas as pd

from collections import OrderedDict

# from matplotlib import pyplot as plt
# from matplotlib.colors import Normalize
# from numpy import around

import os

import argparse

# %%
"""
Enable passing some keyword arguments from command line.
This does not affect the Jupyter notebook.
"""
# try:
parser = argparse.ArgumentParser()

parser.add_argument('--experiments_dir', action='store', dest='experiments_dir',
                    help='Specify the path to the experiments directory. '+\
                        '(e.g. "/cluster/scratch/raiskiny/experiments_sim_070/")', 
                    type=str,
                    default=None)
# Out:
# _StoreAction(option_strings=['--experiments_dir'], dest='experiments_dir', nargs=None, const=None, default=None, type=<class 'str'>, choices=None, help='Specify the path to the experiments directory. (e.g. "/cluster/scratch/raiskiny/experiments_sim_070/")', metavar=None)

# %%
args, unknown = parser.parse_known_args()

if args.experiments_dir is None:
    raise ValueError('Please specify the experiments directory, using the flag "--experiments_dir"')

experiments_dir = args.experiments_dir
# fix file name syntax
if experiments_dir[-1] != '/':
    experiments_dir += '/'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b47f5654ae9f> in <module>()
#       2
#       3 if args.experiments_dir is None:
# ----> 4     raise ValueError('Please specify the experiments directory, using the flag "--experiments_dir"')
#
# ValueError: Please specify the experiments directory, using the flag "--experiments_dir"

# %%
"""
Scalars tags (not all but most of them):
Mean_Reciprocal_Rank/Mean_Reciprocal_Rank_test
Accuracy/Accuracy_test
In_top_5/In_top_5_test
Cost_function/Total_cost_test
Cost_function_additional_metrics/Cross_entropy_test

attributes
wall_time
step
value
"""


def get_optimal_event(scalars, selection_func):
    """
    Inputs are list of ScalarEvent and a selection function (either min or max).
    e.g. for accuracy, max should be selected, while for cost, min is appropriate.
    Returns the "optimal" event, i.e. the event where the optimal value was achieved.
    """
    if selection_func not in (min, max):
        raise ValueError('selection_func should be either min or max, got unexpected {}'
                         .format(selection_func.__name__))
    
    # optimal value
    optimal_val = selection_func(
        [event.value for event in scalars])
    # optimal event (corresponding to the optimal value)
    optimal_event = [event for event in scalars 
                     if event.value == optimal_val][0]
    
    return optimal_event


def get_all_optimals(log_dir, event_acc):
    """
    Inputs are log_dir (e.g. as from child_dir) 
        and event_acc is the event accumulator.
    Gets optimal events (using 'get_optimal_event') for 
        total cost, Mean Reciprocal Rank and accuracy.
    Returns the three optimal events (optimal_cost, optimal_mrr, optimal_accuracy),
        as well as the three ScalarEvent lists (total_cost, mrr, accuracy)
    """
    # get ScalarEvent lists
    total_cost = event_acc.Scalars(log_dir, 'Cost_function/Total_cost_test')
    mrr = event_acc.Scalars(log_dir, 'Mean_Reciprocal_Rank/Mean_Reciprocal_Rank_test')
    accuracy = event_acc.Scalars(log_dir, 'Accuracy/Accuracy_test')

    # get optimal events
    optimal_cost = get_optimal_event(total_cost, min)
    optimal_mrr = get_optimal_event(mrr, max)
    optimal_accuracy = get_optimal_event(accuracy, max)

    return (optimal_cost, optimal_mrr, optimal_accuracy, 
            total_cost, mrr, accuracy)


def value_at_other_optimal(scalars, optimal_event):
    """
    Inputs are scalars, a list of ScalarEvent and 
        optimal_event, an optimal ScalarEvent.
    Retruns the value from scalars at the optimal_event step.
    e.g. value_at_other_optimal(accuracy, optimal_cost) returns
        the accuracy value at the step where cost was optimal.
    """
    return [event.value for event in scalars 
            if event.step == optimal_event.step][0]


def metrics_dict_from_log(log_dir, 
                          event_acc=None, 
                          optimal_cost=None, 
                          optimal_mrr=None, 
                          optimal_accuracy=None, 
                          total_cost=None, 
                          mrr=None, 
                          accuracy=None):
    """
    Input log_dir is a Tensorboard log directory
        and event_acc is the event accumulator.
    Other inputs are optional and will be generated if not provided.
    Returns an OrderedDict with the model string (log dir name) and evaluation metrics.
    """
    # check if event_acc is None
    if event_acc is None:
        event_acc = event_multiplexer\
            .EventMultiplexer()\
            .AddRunsFromDirectory(log_dir)
        event_acc.Reload()
    
    # check if all optional input values are None
    if not any(a is not None 
               for a in [optimal_cost, 
                         optimal_mrr, 
                         optimal_accuracy, 
                         total_cost, 
                         mrr, 
                         accuracy]):
        # get evaluation metrics data from log dir
        (optimal_cost, optimal_mrr, optimal_accuracy, 
         total_cost, mrr, accuracy) = get_all_optimals(log_dir, event_acc)
        
    return OrderedDict(
        [('Model_str', log_dir), 
         ('Cost @ optimal cost', value_at_other_optimal(total_cost, optimal_cost)), 
         ('MRR @ optimal cost', value_at_other_optimal(mrr, optimal_cost)), 
         ('Accuracy @ optimal cost', value_at_other_optimal(accuracy, optimal_cost)), 
         ('step @ optimal cost', optimal_cost.step), 
         
         ('Cost @ optimal MRR', value_at_other_optimal(total_cost, optimal_mrr)), 
         ('MRR @ optimal MRR', value_at_other_optimal(mrr, optimal_mrr)), 
         ('Accuracy @ optimal MRR', value_at_other_optimal(accuracy, optimal_mrr)), 
         ('step @ optimal MRR', optimal_mrr.step), 
         
         ('Cost @ optimal accuracy', value_at_other_optimal(total_cost, optimal_accuracy)), 
         ('MRR @ optimal accuracy', value_at_other_optimal(mrr, optimal_accuracy)), 
         ('Accuracy @ optimal accuracy', value_at_other_optimal(accuracy, optimal_accuracy)),
         ('step @ optimal accuracy', optimal_accuracy.step)
         ])

# %%
# specify path (for parent log dir)
# experiments_dir = './experiments/'

log_parent_dirs = next(os.walk(experiments_dir))[1]

log_parent_dirs = [experiments_dir + elem 
                   for elem in log_parent_dirs]

# log_parent_dirs = [elem for elem in log_parent_dirs
#                    if '4_20' in elem]

# log_parent_dirs = ['logdir_exper_4_20_GRU/',
#                    'logdir_exper_4_20_GRU_bidir/',
#                    'logdir_exper_4_20_LSTM/',
#                    'logdir_exper_4_20_LSTM_bidir/']

# print('cutting short the number of log dirs (else crash)')
# log_parent_dirs = log_parent_dirs[:2]
# log_parent_dirs = log_parent_dirs[:3]
# Out:
# cutting short the number of log dirs (else crash)

# %%
event_accum = event_multiplexer.EventMultiplexer()
for log_dir in log_parent_dirs:
    event_accum = event_accum.AddRunsFromDirectory(log_dir)

# load
event_accum.Reload()  # this might take a bit, depending on number of runs

# event_accum = {index: event_multiplexer\
#                .EventMultiplexer()\
#                .AddRunsFromDirectory(log_dir)\
#                .Reload()
#                for index, log_dir in enumerate(log_parent_dirs)}
# Out:
# INFO:tensorflow:Event Multiplexer initializing.
# INFO:tensorflow:Event Multiplexer done initializing
# INFO:tensorflow:Starting AddRunsFromDirectory: ./experiments/logdir_exper_4_20_GRU
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Done with AddRunsFromDirectory: ./experiments/logdir_exper_4_20_GRU
# INFO:tensorflow:Starting AddRunsFromDirectory: ./experiments/logdir_exper_4_20_GRU_bidir
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Adding events from directory ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Constructing EventAccumulator for ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3
# INFO:tensorflow:Done with AddRunsFromDirectory: ./experiments/logdir_exper_4_20_GRU_bidir
# INFO:tensorflow:Beginning EventMultiplexer.Reload()
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492767688.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492991839.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492715211.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492810511.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1493128321.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492850375.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492980521.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492700372.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1493035653.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1493025369.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492961410.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492844520.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492694032.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1493117899.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492722446.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492888708.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492798548.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492973752.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492826436.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492746691.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492838220.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492707797.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492942345.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1493067699.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492786325.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1493014162.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492869740.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492948924.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492913551.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492757549.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492718841.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1493085530.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492696599.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492919578.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492955189.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492929852.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1493107338.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1493138938.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492875844.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1493074339.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492882168.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492704080.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492735548.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492820849.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1493003075.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492743049.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1493149306.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492865849.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492780132.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492895009.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1493056993.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492773954.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492711540.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492967748.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492728122.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492907351.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492814507.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492901207.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1493096276.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492936110.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492832131.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,tanh,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492725766.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492761480.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492792431.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492739290.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1493046126.e2369
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492753934.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492750296.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492856638.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492731817.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU/GRU,bidir=F,noisy_tanh,learn_p=F,noise_alpha=0.9,noise_half_normal=F,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=128,l2_wieght_reg=1.0E-03,target_rep_weight=0.3/events.out.tfevents.1492804430.e2360
# INFO:tensorflow:No path found after ./experiments/logdir_exper_4_20_GRU_bidir/GRU,bidir=T,noisy_tanh,learn_p=T,noise_alpha=1.15,noise_half_normal=T,keep_infreq_labels=F,learn_rate=1.0E-02,keep_prob=0.7,one_hot,hidden_state_size=64,l2_wieght_reg=1.0E-04,target_rep_weight=0.3/events.out.tfevents.1492923520.e2369
# INFO:tensorflow:Finished with EventMultiplexer.Reload()

# %%
print('='*50)
print('Done loading {} Tensorboard runs'.format(len(event_accum.Runs())))
print('='*50)
# Out:
# ==================================================
# Done loading 72 Tensorboard runs
# ==================================================

# %%
# get a list of all subfolders in the parent log dir
child_dir = [sub_dir
             for log_dir in log_parent_dirs 
             for sub_dir in next(os.walk(log_dir))[1]]

# %%
parent_dir_metrics = [metrics_dict_from_log(log_dir, event_accum)
                      for log_dir in child_dir]

# %%
exper_metrics = pd.DataFrame(parent_dir_metrics)
# correct the Model_str column to index
# exper_metrics.set_index(keys='Model_str', 
#                         inplace=True, verify_integrity=True)

# sort rows by value
exper_metrics.sort_values(by='MRR @ optimal MRR', ascending=False, 
                          inplace=True)
# exper_metrics.sort_values(by='Cost @ optimal cost', ascending=True, 
#                           inplace=True)

exper_metrics = exper_metrics\
    .style.background_gradient(
    cmap='spring', low=.5, high=0)\
    .format(  # format all float values
        {col: '{:.2%}' 
         for col in exper_metrics.columns 
         if any(word in col
                for word in ['Accuracy @', 
                             'MRR @', 
                             'Cost @'])})\
    .format(
        {'Cost @ optimal cost' : '{:.3f}', 
             'Cost @ optimal MRR' : '{:.3f}', 
             'Cost @ optimal accuracy' : '{:.3f}'})\
    .apply(lambda x: ["background: greenyellow" # color str cells based on their model type, hacky I know
                      if isinstance(v, str) and 'GRU,bidir=F' in v 
                      else "background: hotpink" if isinstance(v, str) and 'GRU,bidir=T' in v 
                      else "background: coral" if isinstance(v, str) and 'LSTM,bidir=F' in v 
                      else "background: olive" if isinstance(v, str) and 'LSTM,bidir=T' in v 
                      else "" for v in x], 
           axis = 1)
    
df_style = exper_metrics.export()
# can reuse styles with
# Styler.use(exper_metrics.export())

# %%
exper_metrics
# Out:
#         <style  type="text/css" >
#
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col0 {
#
#                 background:  greenyellow;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col1 {
#
#                 background-color:  #ff7b84;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col2 {
#
#                 background-color:  #fffd02;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col3 {
#
#                 background-color:  #ffff00;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col4 {
#
#                 background-color:  #ffff00;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col5 {
#
#                 background-color:  #ff7788;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col6 {
#
#                 background-color:  #ffff00;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col7 {
#
#                 background-color:  #ffff00;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col8 {
#
#                 background-color:  #fffe01;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col9 {
#
#                 background-color:  #ff7788;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col10 {
#
#                 background-color:  #ffff00;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col11 {
#
#                 background-color:  #ffff00;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row0_col12 {
#
#                 background-color:  #fffe01;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col0 {
#
#                 background:  greenyellow;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col1 {
#
#                 background-color:  #ff926d;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col2 {
#
#                 background-color:  #ffff00;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col3 {
#
#                 background-color:  #fff906;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col4 {
#
#                 background-color:  #ffec13;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col5 {
#
#                 background-color:  #ff8877;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col6 {
#
#                 background-color:  #fffb04;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col7 {
#
#                 background-color:  #fff00f;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col8 {
#
#                 background-color:  #ffec13;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col9 {
#
#                 background-color:  #ff8877;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col10 {
#
#                 background-color:  #fffb04;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col11 {
#
#                 background-color:  #fff00f;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row1_col12 {
#
#                 background-color:  #ffec13;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col0 {
#
#                 background:  greenyellow;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col1 {
#
#                 background-color:  #ff7689;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col2 {
#
#                 background-color:  #fff20d;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col3 {
#
#                 background-color:  #ffed12;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col4 {
#
#                 background-color:  #ffcd32;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col5 {
#
#                 background-color:  #ff718e;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col6 {
#
#                 background-color:  #fff50a;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col7 {
#
#                 background-color:  #fff00f;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col8 {
#
#                 background-color:  #ffd22d;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col9 {
#
#                 background-color:  #ff7788;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col10 {
#
#                 background-color:  #fff20d;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col11 {
#
#                 background-color:  #fff00f;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row2_col12 {
#
#                 background-color:  #ffc13e;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row3_col0 {
#
#                 background:  hotpink;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row3_col1 {
#
#                 background-color:  #ff7f80;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row3_col2 {
#
#                 background-color:  #fff20d;
#
#                 : ;
#
#             }
#
#             #T_ab00f22e_536a_11e7_a261_40e230b15473row3_col3 {
#
#                 background-color:  #fff906;

# %%
fname = list(filter(None, experiments_dir.split('/')))[-1]
fname += '.csv'

exper_metrics.data.to_csv(
    fname, 
    sep=';')
# GRU seems to the highest performer
# GRU bidir is not far behind
# LSTM comes slightly after
# LSTM bidir seems to be the clear underperformer
